# %% [markdown]
# # SQL Querying

# %% [markdown]
# This notebook can be used to query tables in the Congressional Data database. In order to use this notebook, you will need to set an environment variable 'CD_DWH' to the database connection string. If you do not have the credentials, please slack us at #datasci-congressdata channel and/or talk to a project lead.
#
# **It is best practice to not hard code database URI strings directly in notebooks or code as when we push to Github, that would mean credentials are public for anyone to see.**

# %%
import os
import sys

import pandas as pd
pd.options.display.max_columns = 999
import sqlalchemy as sqla
from sqlalchemy import create_engine

DB_URI = os.getenv('CD_DWH')
engine = create_engine(DB_URI)

# %%
# Checking that the Kernel is using the Conda environment datasci-congressional-data
# Below you should see something like '/Users/Username/anaconda3/envs/datasci-congressional-data/bin/python
# If you do NOT see "datasci-congressional-data" this means you are not in the right Python Environment
# Please make sure you have gone through the onboarding docs and/or talk to a project lead.
sys.executable
# Out:
# '/Users/VincentLa/anaconda3/envs/datasci-congressional-data/bin/python'

# %% [markdown]
# Below are the tables that currently exist in the database!

# %%
QUERY = """
select *
from information_schema.tables
where table_schema not in ('information_schema', 'pg_catalog', 'public')
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#               table_catalog   table_schema  \
# 0  datascicongressionaldata    data_ingest
# 1  datascicongressionaldata    data_ingest
# 2  datascicongressionaldata    data_ingest
# 3  datascicongressionaldata  trg_analytics
# 4  datascicongressionaldata  stg_analytics
#
#                                    table_name  table_type  \
# 0              maplight__california_candidate  BASE TABLE
# 1                  maplight__california_other  BASE TABLE
# 2  sfdata__campaign_finance_form460_schedulea  BASE TABLE
# 3                     candidate_contributions  BASE TABLE
# 4                 stg_candidate_contributions  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
# 4                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None

# %% [markdown]
# ## Query Example

# %%
QUERY = """
select
  *
from trg_analytics.candidate_contributions
limit 10
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#         transaction_type election_cycle    election  \
# 0  Monetary Contribution           2015  2016-11-08
# 1  Monetary Contribution           2015  2016-11-08
# 2  Monetary Contribution           2015  2016-11-08
# 3  Monetary Contribution           2015  2016-11-08
# 4  Monetary Contribution           2015  2016-11-08
# 5  Monetary Contribution           2015  2016-11-08
# 5    NOT CURRENTLY SUPPORTED               State Senate
# 6    NOT CURRENTLY SUPPORTED               State Senate
# 7    NOT CURRENTLY SUPPORTED               State Senate
# 8    NOT CURRENTLY SUPPORTED               State Senate
# 9    NOT CURRENTLY SUPPORTED               State Senate
#
#   recipient_candidate_district  \
# 0                          5.0
# 1                          5.0
# 2                          5.0
# 3                          5.0
# 4                          5.0
# 5                          5.0
# 6                          5.0
# 7                          5.0
# 8                          5.0
# 9                          5.0
#
#                                           donor_name   donor_city donor_state  \
# 0  Stanislaus and Tuolumne Counties Central Labor...      Modesto          CA
# 1                                Withrow, Patrick T.      Escalon          CA
# 2                                Yourvoterguide Inc.   Sacramento          CA
# 3                              AFSCME Local 2620 PAC      Burbank          CA
# 4           Amgen Inc. State Political Contributions   Alexandria          VA
# 5           California Assn Of Nurse Anesthetist PAC   Sacramento          CA
# 6                                Charter Schools PAC   Sacramento          CA
# 7         CIPAC State CA Independent Petroleum Assoc       Irvine          CA
# 8                         General Motors Company PAC   Washington          DC
# 9                  Holly J. Mitchell for Senate 2018  Los Angeles          CA
#
#   donor_zip_code      donor_employer         donor_occupation  \
# 0          95354                None  NOT CURRENTLY SUPPORTED
# 1          95320  San Joaquin County  NOT CURRENTLY SUPPORTED
# 2          95814                None  NOT CURRENTLY SUPPORTED
# 3          91505                None  NOT CURRENTLY SUPPORTED
# 4          22303                None  NOT CURRENTLY SUPPORTED
# 5          95814                None  NOT CURRENTLY SUPPORTED
# 6          95814                None  NOT CURRENTLY SUPPORTED
# 7          92618                None  NOT CURRENTLY SUPPORTED
# 8          20001                None  NOT CURRENTLY SUPPORTED
# 9          90017                None  NOT CURRENTLY SUPPORTED
#
#   donor_organization donor_industry        donor_entity_type  \
# 0                COM         746639  NOT CURRENTLY SUPPORTED
# 1                IND              0  NOT CURRENTLY SUPPORTED
# 2                OTH              0  NOT CURRENTLY SUPPORTED
# 3                COM         850523  NOT CURRENTLY SUPPORTED
# 4                COM              0  NOT CURRENTLY SUPPORTED
# 5                COM         811300  NOT CURRENTLY SUPPORTED
# 6                COM        1302433  NOT CURRENTLY SUPPORTED
# 7                COM         822237  NOT CURRENTLY SUPPORTED
# 8                COM         790461  NOT CURRENTLY SUPPORTED
# 9                COM        1373775  NOT CURRENTLY SUPPORTED
#
#         donor_committee_id     donor_committee_name donor_committee_type  \
# 0  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 1  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 2  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 3  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 4  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 5  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 6  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 7  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 8  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
# 9  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED                 None
#
#   donor_committee_party
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
