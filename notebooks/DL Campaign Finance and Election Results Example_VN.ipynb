# %%
# System Modules
import os
import sys
import datetime as dt
sys.path.append('../')

# Data Science Modules
import numpy as np
import pandas as pd
from plotnine import *  # Polluting name space sorry!!
import matplotlib.pyplot as plt
# %matplotlib inline

# SQL Modules
import sqlalchemy as sa
from sqlalchemy import create_engine
from utilities import sql_utils as su

# Deep Learning Modules
import keras
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
# from keras.preprocessing.text import Tokenizer

# from utilities import model_eval_utils as meu

DWH = os.getenv('CD_DWH')
engine = create_engine(DWH)

pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
QUERY = su.get_sql_as_string('../notebooks/sql/campaign_finance_and_election_results_VN')
with engine.begin() as conn:
    df = pd.read_sql(QUERY, conn)
#     df.set_index('candidate_name', inplace=True)

# %%
df
# Out:
#             candidate_name  total_transaction  \
# 0              larryaceves         468831.900
# 1              danteacosta          47600.000
# 2              danteacosta        1168239.910
# 3           richardalarcon          54881.170
# 4           richardalarcon        1374456.080
# 5           richardalarcon         629978.180
# 6              travisallen          73050.000
# 7              travisallen         150000.000
# 8              travisallen        1726041.360
# 9            peteramundson          19925.000
# 10      michaeldantonovich        1822447.130
# 11         joaquinarambula          57114.300
# 12         joaquinarambula        2159052.510
# 13              toniatkins         590826.210
# 14          catharinebaker          98300.000
# 15          catharinebaker        4551669.540
# 16               karenbass        3159026.150
# 17                jimbeall        1170522.810
# 18                jimbeall        3174601.050
# 19           xavierbecerra        2353186.260
# 20           xavierbecerra        1066500.000
# 21              marcberman          66700.000
# 22              marcberman        1285450.470
# 23            frankbigelow        3123572.710
# 24            richardbloom          44947.230
# 25            richardbloom        2221026.700
# 26           raulbocanegra        4524723.600
# 27                robbonta        1088839.470
# 28                robbonta        3704314.210
# 29          stevenbradford         129008.210
# 30          stevenbradford        2068889.550
# 31          stevenbradford        1743851.020
# 32              ryankbrown          13099.070
# 33           juliabrownley        1379089.750
# 34              baronbruno          31868.660
# 35              bobbrunton          11242.930
# 36             autumnburke        1987607.700
# 37             autumnburke         340294.080
# 38           annacaballero          81140.000
# 39           annacaballero        1824033.750
# 40           annacaballero        3216886.410
# 41              noracampos        1713874.980
# 42              noracampos         548430.510
# 43             briancaples          20302.000
# 44            tonycardenas         109025.000
# 45            tonycardenas         329064.800
# 46        sabrinacervantes          68333.330
# 47        sabrinacervantes        2488595.830
# 48    karinacervantezalejo         463081.350
# 49              paulchabot              0.000
# 50              paulchabot            600.000
# 51           linglingchang          80000.000
# 52           linglingchang         791215.080
# 53           linglingchang        3301722.180
# 54             rockychavez         146416.100
# 55             rockychavez        1021248.030
# 56             phillipchen        1286593.560
# 57              johnchiang        6849055.260
# 58              johnchiang        1049231.310
# 59              johnchiang        6307935.800
# 60              johnchiang        4495107.620
# 61            clairechiara           3431.910
# 62               davidchiu         660681.830
# 63               davidchiu        2154716.590
# 64                 judychu        2541191.380
# 65                 judychu        2054622.400
# 66               kansenchu          27600.000
# 67               kansenchu        1132883.670
# 68              gregconlon          46847.280
# 69              gregconlon         286016.700
# 70        cherylcookkallio        3064946.900
# 71                paulcook         -46150.000
# 72               kencooley          90612.480
# 73               kencooley        6311813.740
# 74               kencooley          23430.920
# 75             stevecooley        5542737.840
# 76               jimcooper         308202.830
# 77               jimcooper        2382810.180
# 78               loucorrea         430475.220
# 79               loucorrea         154015.230
# 80               loucorrea         812938.360
# 81               loucorrea        5566493.080
# 82                jimcosta          96103.880
# 83                jimcosta          27640.000
# 84        jordancunningham          62675.000
# 85        jordancunningham        1455247.510
# 86              briandahle          76500.000
# 87              briandahle        1768050.430
# 88                 tomdaly        2678522.010
# 89                 tomdaly         229261.950
# 90          markdesaulnier        1209405.350
# 91          markdesaulnier        1125571.140
# 92              jeffdenham        1135647.800
# 93              jeffdenham          13966.860
# 94              jeffdenham        5407814.120
# 95          markdesaulnier          51721.000
# 96          markdesaulnier         579467.430
# 97              hectordiaz         168902.190
# 98                billdodd         366343.090
# 99                billdodd        1883851.330
# 100               billdodd        2332541.570
# 101             stevefazio        1351208.790
# 102             heathflora          11600.000
# 103             heathflora         433726.510
# 104               stevefox        2752784.070
# 105          laurafriedman         307830.000
# 106          laurafriedman          13800.000
# 107          laurafriedman        1092404.480
# 108        warrentfurutani           2000.000
# 109              tedgaines            100.000
# 110              tedgaines            100.000
# 111              tedgaines          64700.000
# 112              tedgaines          64700.000
# 113       cathleengalgiani         334020.000
# 114       cathleengalgiani         352300.000
# 115       cathleengalgiani          84986.640
# 116       cathleengalgiani        4997897.140
# 117       cathleengalgiani        5202844.380
# 118         jamesgallagher         166400.820
# 119         jamesgallagher         962373.920
# 120          johngaramendi         755892.990
# 121          johngaramendi        5584366.690
# 122          johngaramendi        7486229.040
# 123         cristinagarcia         937060.470
# 124         cristinagarcia        1587917.650
# 125          eduardogarcia          27600.000
# 126          eduardogarcia        1393814.660
# 127            mikeagipson         293587.350
# 128             toddgloria          38700.000
# 129             toddgloria         916933.090
# 130             ronaldgold         119448.520
# 131             jimmygomez        2523879.580
# 132             jimmygomez         445664.470
# 133         lorenagonzalez           2320.160
# 134             timgrayson         308101.500
# 135             timgrayson        1004390.190
# 136               leohamel           4750.000
# 137          matthewharper           9500.000
# 138          matthewharper         520110.390
# 139          kamaladharris       14396670.570
# 140          kamaladharris        1064348.080
# 141          caseychiggins          23073.620
# 142            chrisholden         153250.000
# 143            chrisholden        2762212.020
# 144            jacquiirwin          32600.000
# 145            jacquiirwin        3965649.820
# 146      hannahbethjackson        2324370.810
# 147      hannahbethjackson         609797.210
# 148      hannahbethjackson        4130258.790
# 149              davejones        1542866.220
# 150              davejones        7989302.760
# 151              davejones         148712.500
# 152              davejones        2466705.680
# 153             palmerkain          49826.900
# 154               ashkalra          31100.000
# 155               ashkalra        1349180.610
# 156           neelkashkari        7256526.590
# 157         ardykassakhian        1279833.940
# 158             kevinkiley         727428.140
# 159                janekim          47061.670
# 160                janekim        1558155.700
# 161               youngkim           4440.790
# 162            steveknight         760806.500
# 163            steveknight         404207.790
# 164            douglamalfa        1783430.830
# 165            douglamalfa        1507370.990
# 166            ricardolara         362240.000
# 167            ricardolara         224000.000
# 168            ricardolara        1605211.580
# 169            ricardolara        2480537.000
# 170          dawnortizlegg        2716771.460
# 171             marclevine          22600.000
# 172             marclevine        2772311.480
# 173             pattylopez         139874.040
# 174                evanlow         322623.390
# 175                evanlow        2580873.470
# 176          alanlowenthal          93547.690
# 177          alanlowenthal         702450.120
# 178          alanlowenthal        1867643.140
# 179          rubenmacareno           1301.130
# 180       brianmaienschein        2151857.830
# 181          abelmaldonado         517796.790
# 182          abelmaldonado        2181853.810
# 183          abelmaldonado         266752.000
# 184          abelmaldonado        1974123.740
# 185          abelmaldonado        5374871.430
# 186              chadmayes        1529240.190
# 187              chadmayes        1171411.100
# 188          kevinmccarthy         460579.850
# 189          kevinmccarthy        2879619.460
# 190           kevinmccarty          54100.000
# 191           kevinmccarty        2015955.190
# 192           kevinmccarty         124189.000
# 193          abigailmedina           2500.000
# 194             josemedina         115500.000
# 195        melissamelendez        1324438.060
# 196            gwenlmorris          62408.320
# 197            kevinmullin          21750.000
# 198            kevinmullin        2308730.680
# 199           almuratsuchi         475531.390
# 200           almuratsuchi        9519825.790
# 201          adrinnazarian          18800.000
# 202          adrinnazarian        2209397.020
# 203             ronnehring          64478.270
# 204           kerryjnelson           5100.000
# 205            gavinnewsom       18161447.580
# 206            gavinnewsom        8636716.200
# 207            gavinnewsom        3286080.000
# 208          madisonnguyen        1159518.930
# 209        patrickodonnell          31800.000
# 210        patrickodonnell        1894017.260
# 211           jayobernolte           2400.000
# 212           jayobernolte        1100830.130
# 213           clintolivier         738412.460
# 214           clintolivier          20034.110
# 215           karinaonofre           1001.130
# 216           karinaonofre         213458.020
# 217            alexpadilla         227454.600
# 218            alexpadilla        4622648.560
# 219            alexpadilla        4023958.870
# 220          seanjaypanahi          78869.630
# 221           jimpatterson           8500.000
# 222           jimpatterson        1579372.430
# 223           jimpatterson           8500.000
# 224           petepeterson            100.000
# 225       sharonquirksilva        4477092.510
# 226       sharonquirksilva        4874718.800
# 227                jimreed         153055.380
# 228            richardreed          22533.710
# 229          anthonyrendon        1585867.870
# 230          anthonyrendon        3716225.540
# 231            johnrenison         134017.120
# 232            eloisereyes         184260.300
# 233          sierraroberts           4300.000
# 234       freddierodriguez          15689.840
# 235       freddierodriguez        1893247.630
# 236          gregrodriguez          28578.660
# 237          gregrodriguez         183449.580
# 238           angelarupert          60479.000
# 239         theresasanford          11296.500
# 240         miguelsantiago         101675.000
# 241         miguelsantiago        2695098.770
# 242            bradsherman         166371.500
# 243            bradsherman          22250.000
# 244           nancyskinner         211435.560
# 245           nancyskinner        2370673.750
# 246           nancyskinner        2386333.330
# 247  roseannslonskybreault           6800.000
# 248           christysmith          42500.000
# 249           christysmith        1845907.670
# 250           jackiespeier          74800.000
# 251          marcsteinorth          68888.000
# 252          marcsteinorth        4292841.860
# 253             henrystern          62500.000
# 254             henrystern        3180168.160
# 255              jeffstone           3447.000
# 256              markstone          40000.000
# 257              markstone        1017766.880
# 258         tonystrickland        1105238.580
# 259         tonystrickland        4322560.240
# 260         tonystrickland        5467183.090
# 261       ashleyswearengin        1355768.810
# 262           tonythurmond         386100.000
# 263           tonythurmond        2502515.720
# 264           tonythurmond         893064.000
# 265               philting         152645.120
# 266               philting        3404819.870
# 267           ritatopalian         108675.000
# 268           tomtorlakson              0.000
# 269           tomtorlakson        1280527.740
# 270           tomtorlakson         861001.260
# 271           tomtorlakson        5689199.910
# 272           normajtorres          40548.000
# 273           marshalltuck         519855.000
# 274           marshalltuck        3808796.060
# 275             juanvargas           9000.000
# 276           vickiveenker         736233.740
# 277    ofeliavelardegarcia           6350.000
# 278               kenvogel         490647.250
# 279           mariewaldron        1724468.380
# 280            mimiwalters        1561354.150
# 281            mimiwalters        1561354.150
# 282            mimiwalters        2584255.930
# 283            mimiwalters        2584255.930
# 284            mimiwalters        1116339.810
# 285            mimiwalters        1116339.810
# 286          shirleynweber        1913474.180
# 287              luisawong          17281.910
# 288                jimwood          51300.000
# 289           marikoyamada         218443.030
# 290              bettytyee        1049203.320
# 291              bettytyee        3207904.620
# 292              bettytyee         380687.760
#
#                recipient_candidate_office  is_winner
# 0    Superintendent of Public Instruction          0
# 1                                   Other          1
# 2                          State Assembly          1
# 3                                   Other          0
# 4                          State Assembly          0
# 5                            State Senate          0
# 6                                Governor          1
# 7                                   Other          1
# 8                          State Assembly          1
# 9                          State Assembly          0
# 10                           State Senate          0
# 11                                  Other          1
# 12                         State Assembly          1
# 13                         State Assembly          1
# 14                                  Other          1
# 15                         State Assembly          1
# 16                         State Assembly          1
# 17                         State Assembly          1
# 18                           State Senate          1
# 19                       Attorney General          1
# 20                                  Other          1
# 21                                  Other          1
# 22                         State Assembly          1
# 23                         State Assembly          1
# 24                                  Other          1
# 25                         State Assembly          1
# 26                         State Assembly          1
# 27                                  Other          1
# 28                         State Assembly          1
# 29                                  Other          1
# 30                         State Assembly          1
# 31                           State Senate          1
# 32                         State Assembly          0
# 33                         State Assembly          1
# 34                         State Assembly          0
# 35                         State Assembly          0
# 36                                  Other          1
# 37                         State Assembly          1
# 38                                  Other          1
# 39                         State Assembly          1
# 40                           State Senate          1
# 41                         State Assembly          0
# 42                           State Senate          0
# 43                         State Assembly          0
# 44                     Secretary of State          1
# 45                         State Assembly          1
# 46                                  Other          1
# 47                         State Assembly          1
# 48                         State Assembly          0
# 49                                  Other          0
# 50                         State Assembly          0
# 51                                  Other          0
# 52                         State Assembly          0
# 53                           State Senate          0
# 54                                  Other          1
# 55                         State Assembly          1
# 56                         State Assembly          1
# 57                               Governor          0
# 58                                  Other          0
# 59                       State Controller          0
# 60                        State Treasurer          0
# 61                         State Assembly          0
# 62                                  Other          1
# 63                         State Assembly          1
# 64                  Board of Equalization          1
# 65                         State Assembly          1
# 66                                  Other          1
# 67                         State Assembly          1
# 68                         State Assembly          0
# 69                        State Treasurer          0
# 70                         State Assembly          0
# 71                         State Assembly          1
# 72                                  Other          1
# 73                         State Assembly          1
# 74                           State Senate          1
# 75                       Attorney General          0
# 76                                  Other          1
# 77                         State Assembly          1
# 78                       Attorney General          1
# 79                  Board of Equalization          1
# 80                         State Assembly          1
# 81                           State Senate          1
# 82                  Board of Equalization          1
# 83                           State Senate          1
# 84                                  Other          1
# 85                         State Assembly          1
# 86                                  Other          1
# 87                         State Assembly          1
# 88                                  Other          1
# 89                         State Assembly          1
# 90                         State Assembly          1
# 91                           State Senate          1
# 92                    Lieutenant Governor          1
# 93                         State Assembly          1
# 94                           State Senate          1
# 95                         State Assembly          1
# 96                           State Senate          1
# 97                         State Assembly          0
# 98                                  Other          1
# 99                         State Assembly          1
# 100                          State Senate          1
# 101                          State Senate          0
# 102                                 Other          1
# 103                        State Assembly          1
# 104                        State Assembly          0
# 105                   City Council Member          1
# 106                                 Other          1
# 107                        State Assembly          1
# 108                          State Senate          0
# 109                  Board of Supervisors          1
# 110                  Board of Supervisors          0
# 111                        State Assembly          1
# 112                        State Assembly          0
# 113                 Board of Equalization          1
# 114                                 Other          1
# 115                    Secretary of State          1
# 116                        State Assembly          1
# 117                          State Senate          1
# 118                                 Other          1
# 119                        State Assembly          1
# 120                              Governor          1
# 121                Insurance Commissioner          1
# 122                   Lieutenant Governor          1
# 123                                 Other          1
# 124                        State Assembly          1
# 125                                 Other          1
# 126                        State Assembly          1
# 127                        State Assembly          1
# 128                                 Other          1
# 129                        State Assembly          1
# 130                      Attorney General          0
# 131                                 Other          1
# 132                        State Assembly          1
# 133                        State Assembly          1
# 134                                 Other          1
# 135                        State Assembly          1
# 136                        State Assembly          0
# 137                                 Other          1
# 138                        State Assembly          1
# 139                      Attorney General          1
# 140                              Governor          1
# 141                        State Assembly          0
# 142                                 Other          1
# 143                        State Assembly          1
# 144                                 Other          1
# 145                        State Assembly          1
# 146                                 Other          1
# 147                        State Assembly          1
# 148                          State Senate          1
# 149                      Attorney General          1
# 150                Insurance Commissioner          1
# 151                                 Other          1
# 152                        State Assembly          1
# 153                          State Senate          0
# 154                                 Other          1
# 155                        State Assembly          1
# 156                              Governor          0
# 157                        State Assembly          0
# 158                        State Assembly          1
# 159                                 Other          0
# 160                          State Senate          0
# 161                        State Assembly          0
# 162                        State Assembly          1
# 163                          State Senate          1
# 164                        State Assembly          1
# 165                          State Senate          1
# 166                Insurance Commissioner          1
# 167                                 Other          1
# 168                        State Assembly          1
# 169                          State Senate          1
# 170                        State Assembly          0
# 171                                 Other          1
# 172                        State Assembly          1
# 173                        State Assembly          0
# 174                                 Other          1
# 175                        State Assembly          1
# 176                   Lieutenant Governor          1
# 177                        State Assembly          1
# 178                          State Senate          1
# 179                        State Assembly          0
# 180                        State Assembly          1
# 181                              Governor          0
# 182                   Lieutenant Governor          0
# 183                        State Assembly          0
# 184                      State Controller          0
# 185                          State Senate          0
# 186                                 Other          1
# 187                        State Assembly          1
# 188                   Lieutenant Governor          1
# 189                        State Assembly          1
# 190                                 Other          1
# 191                        State Assembly          1
# 192                        State Assembly          1
# 193                        State Assembly          0
# 194                        State Assembly          1
# 195                        State Assembly          1
# 196                        State Assembly          0
# 197                                 Other          1
# 198                        State Assembly          1
# 199                                 Other          1
# 200                        State Assembly          1
# 201                                 Other          1
# 202                        State Assembly          1
# 203                   Lieutenant Governor          0
# 204                        State Assembly          0
# 205                              Governor          1
# 206                   Lieutenant Governor          1
# 207                                 Other          1
# 208                        State Assembly          0
# 209                                 Other          1
# 210                        State Assembly          1
# 211                                 Other          1
# 212                        State Assembly          1
# 213                        State Assembly          0
# 214                          State Senate          0
# 215                                 Other          0
# 216                        State Assembly          0
# 217                                 Other          0
# 218                    Secretary of State          0
# 219                          State Senate          0
# 220                        State Assembly          0
# 221                                 Other          1
# 222                        State Assembly          1
# 223                          State Senate          1
# 224                    Secretary of State          0
# 225                                 Other          1
# 226                        State Assembly          1
# 227                        State Assembly          0
# 228                          State Senate          0
# 229                                 Other          1
# 230                        State Assembly          1
# 231                          State Senate          0
# 232                        State Assembly          1
# 233                        State Assembly          0
# 234                                 Other          1
# 235                        State Assembly          1
# 236                                 Other          0
# 237                        State Assembly          0
# 238                        State Assembly          0
# 239                        State Assembly          0
# 240                                 Other          1
# 241                        State Assembly          1
# 242                 Board of Equalization          1
# 243                                 Other          1
# 244                                 Other          1
# 245                        State Assembly          1
# 246                          State Senate          1
# 247                        State Assembly          0
# 248                                 Other          0
# 249                        State Assembly          0
# 250                   Lieutenant Governor          1
# 251                                 Other          1
# 252                        State Assembly          1
# 253                                 Other          1
# 254                          State Senate          1
# 255                          State Senate          0
# 256                                 Other          1
# 257                        State Assembly          1
# 258                        State Assembly          0
# 259                      State Controller          0
# 260                          State Senate          0
# 261                      State Controller          0
# 262                                 Other          1
# 263                        State Assembly          1
# 264  Superintendent of Public Instruction          1
# 265                                 Other          1
# 266                        State Assembly          1
# 267                        State Assembly          0
# 268                                 Other          1
# 269                        State Assembly          1
# 270                          State Senate          1
# 271  Superintendent of Public Instruction          1
# 272                        State Assembly          1
# 273                                 Other          0
# 274  Superintendent of Public Instruction          0
# 275                        State Assembly          1
# 276                        State Assembly          0
# 277                        State Assembly          0
# 278                        State Assembly          0
# 279                        State Assembly          1
# 280                        State Assembly          1
# 281                        State Assembly          0
# 282                          State Senate          1
# 283                          State Senate          0
# 284                       State Treasurer          1
# 285                       State Treasurer          0
# 286                        State Assembly          1
# 287                        State Assembly          0
# 288                        State Assembly          1
# 289                        State Assembly          0
# 290                 Board of Equalization          0
# 291                      State Controller          0
# 292                      State Controller          0

# %%
df.shape
# Out:
# (293, 4)

# %% [markdown]
# # Data Preparation

# %%
df.groupby('recipient_candidate_office').count()['candidate_name']
# Out:
# recipient_candidate_office
# Attorney General                          6
# Board of Equalization                     6
# Board of Supervisors                      2
# City Council Member                       1
# Governor                                  7
# Insurance Commissioner                    3
# Lieutenant Governor                       8
# Other                                    70
# Secretary of State                        4
# State Assembly                          135
# State Controller                          6
# State Senate                             37
# State Treasurer                           4
# Superintendent of Public Instruction      4
# Name: candidate_name, dtype: int64

# %%
filtered_candidates = df[(df['recipient_candidate_office'] == ('State Senate')) | (df['recipient_candidate_office'] == ('State Assembly')) | (df['recipient_candidate_office'] == ('Other'))]
filtered_candidates.shape
# processed_data = pd.get_dummies(data, columns=['rank'])
# Out:
# (242, 4)

# %%
# One-hot encode recipient candidate office
filtered_candidates = pd.get_dummies(filtered_candidates, columns=['recipient_candidate_office'])

# %%
filtered_candidates.head(10)
# Out:
#         candidate_name  total_transaction  is_winner  \
# 1          danteacosta          47600.000          1
# 2          danteacosta        1168239.910          1
# 3       richardalarcon          54881.170          0
# 4       richardalarcon        1374456.080          0
# 5       richardalarcon         629978.180          0
# 7          travisallen         150000.000          1
# 8          travisallen        1726041.360          1
# 9        peteramundson          19925.000          0
# 10  michaeldantonovich        1822447.130          0
# 11     joaquinarambula          57114.300          1
#
#     recipient_candidate_office_Other  \
# 1                                  1
# 2                                  0
# 3                                  1
# 4                                  0
# 5                                  0
# 7                                  1
# 8                                  0
# 9                                  0
# 10                                 0
# 11                                 1
#
#     recipient_candidate_office_State Assembly  \
# 1                                           0
# 2                                           1
# 3                                           0
# 4                                           1
# 5                                           0
# 7                                           0
# 8                                           1
# 9                                           1
# 10                                          0
# 11                                          0
#
#     recipient_candidate_office_State Senate
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# 5                                         1
# 7                                         0
# 8                                         0
# 9                                         0
# 10                                        1
# 11                                        0

# %%
# Split up data into inputs (X) and outputs (Y)
X = np.array(filtered_candidates)[:, (1, 3, 4, 5)]
# X = np.array(filtered_candidates)[:, 1]
X.astype('float32')
y = keras.utils.to_categorical(filtered_candidates["is_winner"],2)

print("Shape of X:", X.shape)
print("\nShape of y:", y.shape)
print("\nFirst 5 rows of X")
print(X[:5])
print("\nFirst 5 rows of y")
print(y[:5])
# Out:
# Shape of X: (242, 4)
#
# Shape of y: (242, 2)
#
# First 5 rows of X
# [[47600.0 1 0 0]
#  [1168239.91 0 1 0]
#  [54881.17 1 0 0]
#  [1374456.08 0 1 0]
#  [629978.18 0 0 1]]
#
# First 5 rows of y
# [[ 0.  1.]
#  [ 0.  1.]
#  [ 1.  0.]
#  [ 1.  0.]
#  [ 1.  0.]]

# %%
#  Split up into training and testing sets
(X_train, X_test) = X[50:], X[:50]
(y_train, y_test) = y[50:], y[:50]

# Shape of training set (need for model input shape)
print('x_train shape:', X_train.shape)

# Number of training and test samples
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# x_train shape: (192, 4)
# 192 train samples
# 50 test samples

# %% [markdown]
# # Model Architecture

# %%
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(4,)))
model.add(Dropout(.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(.1))
model.add(Dense(2, activation='softmax'))

# Compiling the model
model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 256)               1280
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_51 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 34,434
# Trainable params: 34,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=10, batch_size=30, verbose=0)

# %%
score = model.evaluate(X_train, y_train)
print("\n Training Accuracy:", score[1])
score = model.evaluate(X_test, y_test)
print("\n Testing Accuracy:", score[1])
# Out:
# 192/192 [==============================] - 0s 1ms/step
#
#  Training Accuracy: 0.713541666667
# 50/50 [==============================] - 0s 76us/step
#
#  Testing Accuracy: 0.660000001192

# %% [markdown]
# Future Steps:
# - Add candidate's party status
# - Incorporate candidate's incumbency status
# - Re-run analysis and represent candidate's total donation amount as percentage of overall money spent in the race
